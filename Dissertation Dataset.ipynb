# %%
import pandas as pd 
import numpy as ny 
import IPython.display

# %%
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")

# %%
print (df)
# Out:
#       Source.Name        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     season-0809  30/08/2008      Espanol   Valladolid     1     0   H     0
# 1     season-0809  30/08/2008     Valencia     Mallorca     3     0   H     2
# 2     season-0809  31/08/2008   Ath Bilbao      Almeria     1     3   A     0
# 3     season-0809  31/08/2008   Ath Madrid       Malaga     4     0   H     3
# 4     season-0809  31/08/2008        Betis   Recreativo     0     1   A     0
# 5     season-0809  31/08/2008    La Coruna  Real Madrid     2     1   H     1
# 6     season-0809  31/08/2008     Numancia    Barcelona     1     0   H     1
# 7     season-0809  31/08/2008      Osasuna   Villarreal     1     1   D     0
# 8     season-0809  31/08/2008    Santander      Sevilla     1     1   D     0
# 9     season-0809  31/08/2008     Sp Gijon       Getafe     1     2   A     1
# 10    season-0809  13/09/2008    Barcelona    Santander     1     1   D     0
# ...

# %%
import pandas as pd 
import numpy as ny 
import IPython.display
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")

#Reading Specific Rows
# Slice the result for first 5 rows
print (df[0:5]['HomeTeam'])
# Out:
# 0       Espanol
# 1      Valencia
# 2    Ath Bilbao
# 3    Ath Madrid
# 4         Betis
# Name: HomeTeam, dtype: object

# %%
import pandas as pd 
import numpy as ny 
import IPython.display
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")

#Reading Specific Columns
# Use the multi-axes indexing funtion

print (df.loc[:,['HomeTeam','FTR']])
# Out:
#          HomeTeam FTR
# 0         Espanol   H
# 1        Valencia   H
# 2      Ath Bilbao   A
# 3      Ath Madrid   H
# 4           Betis   A
# 5       La Coruna   H
# 6        Numancia   H
# 7         Osasuna   D
# 8       Santander   D
# 9        Sp Gijon   A
# 10      Barcelona   D
# 11     Valladolid   H
# 12        Almeria   D
# 13         Getafe   D
# 14         Malaga   D
# 15       Mallorca   D
# 16    Real Madrid   H
# 17     Recreativo   A
# 18        Sevilla   H
# 19     Villarreal   H
# 20     Ath Madrid   H
# 21        Espanol   D
# 22        Almeria   H
# 23     Ath Bilbao   H
# 24          Betis   D
# 25      La Coruna   D
# 26       Numancia   A
# 27      Santander   A
# 28       Sp Gijon   A
# 29       Valencia   H
# ...           ...  ..
# 4040      Espanol   D
# 4041       Alaves   D
# 4042   Ath Bilbao   H
# 4043       Getafe   H
# 4044      Sevilla   A
# 4045   Ath Madrid   H
# 4046      Leganes   D
# 4047      Levante   A
# 4048   Valladolid   A
# ...

# %%
import pandas as pd 
import numpy as ny 
import IPython.display
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")

#Reading Specific Columns and Rows
#Use the multi-axes indexing funtion

print (df.loc[[5, 10, 50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000, 4000], ['Source.Name','HomeTeam', 'AwayTeam','FTR','HTR']])
# Out:
#       Source.Name    HomeTeam     AwayTeam FTR HTR
# 5     season-0809   La Coruna  Real Madrid   H   H
# 10    season-0809   Barcelona    Santander   D   D
# 50    season-0809   Barcelona   Ath Madrid   H   H
# 100   season-0809    Valencia     Sp Gijon   A   A
# 200   season-0809  Ath Bilbao       Malaga   H   D
# 300   season-0809  Ath Bilbao    La Coruna   A   D
# 400   season-0910   Barcelona   Ath Madrid   H   H
# 500   season-0910       Xerez    Barcelona   A   D
# 600   season-0910   Barcelona    Santander   H   H
# 700   season-0910     Espanol    Barcelona   D   D
# 800   season-1011  Ath Bilbao    Barcelona   A   D
# 900   season-1011  Ath Madrid    La Coruna   H   H
# 1000  season-1011  Ath Madrid      Sevilla   D   A
# 2000  season-1314       Celta    Barcelona   A   A
# 3000  season-1516  Las Palmas      Espanol   H   H
# 4000  season-1819  Ath Madrid       Getafe   H   H

# %%
import pandas as pd 
import numpy as ny 
import IPython.display
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")


#Reading Specific Columns for a Range of Rows 
# Use the multi-axes indexing funtion

print (df.loc[100:200, ['HomeTeam', 'HTR', 'FTR']])
# Out:
#         HomeTeam HTR FTR
# 100     Valencia   A   A
# 101   Valladolid   D   H
# 102      Almeria   H   H
# 103   Ath Bilbao   H   H
# 104   Ath Madrid   H   H
# 105        Betis   H   H
# 106      Espanol   D   A
# 107       Getafe   A   A
# 108       Malaga   D   D
# 109   Recreativo   D   A
# 110  Real Madrid   H   H
# 111      Sevilla   D   D
# 112   Villarreal   A   A
# 113    Barcelona   A   D
# 114    La Coruna   H   H
# 115     Mallorca   A   D
# 116     Numancia   A   D
# 117      Osasuna   D   H
# 118    Santander   H   H
# 119     Sp Gijon   H   A
# 120       Getafe   H   H
# 121      Sevilla   A   A
# 122      Almeria   D   A
# 123   Ath Bilbao   H   H
# 124   Ath Madrid   H   H
# 125      Espanol   A   A
# 126       Malaga   D   H
# 127   Recreativo   A   A
# 128     Valencia   H   H
# 129   Valladolid   H   H
# ..           ...  ..  ..
# 171     Valencia   H   D
# 172   Ath Madrid   D   A
# 173        Betis   D   A
# 174      Espanol   A   D
# 175     Mallorca   A   A
# ...

# %%
import pandas as pd 
import numpy as np
import IPython.display

#checking for null values 
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
df.isnull()
# Out:
#       Source.Name   Date  HomeTeam  AwayTeam   FTHG   FTAG    FTR   HTHG  \
# 0           False  False     False     False  False  False  False  False
# 1           False  False     False     False  False  False  False  False
# 2           False  False     False     False  False  False  False  False
# 3           False  False     False     False  False  False  False  False
# 4           False  False     False     False  False  False  False  False
# 5           False  False     False     False  False  False  False  False
# 6           False  False     False     False  False  False  False  False
# 7           False  False     False     False  False  False  False  False
# 8           False  False     False     False  False  False  False  False
# 9           False  False     False     False  False  False  False  False
# 10          False  False     False     False  False  False  False  False
# 11          False  False     False     False  False  False  False  False
# ...

# %%
import pandas as pd 
import numpy as np
import IPython.display

#checking for null values in all
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
df.isnull().sum()
# Out:
# Source.Name    0
# Date           0
# HomeTeam       0
# AwayTeam       0
# FTHG           0
# FTAG           0
# FTR            0
# HTHG           0
# HTAG           0
# HTR            0
# HS             0
# AS             0
# HST            0
# AST            0
# HF             0
# AF             0
# HC             0
# AC             0
# HY             0
# AY             0
# HR             0
# AR             0
# dtype: int64

# %%
#example of checking if there is null values 
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
df[df['HomeTeam'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Source.Name, Date, HomeTeam, AwayTeam, FTHG, FTAG, FTR, HTHG, HTAG, HTR, HS, AS, HST, AST, HF, AF, HC, AC, HY, AY, HR, AR]
# Index: []
#
# [0 rows x 22 columns]

# %%
#how Many columns are affeted after checking null 
df.shape
# Out:
# (4070, 22)

# %%
#drop null values if any 

df.dropna(how = 'all').shape
# Out:
# (4070, 22)

# %%
import pandas as pd 
import xgboost as xgb
import sklearn as s 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from IPython.display import display

# %%
logisticRegr = LogisticRegression()

# %%
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
display (df)
# Out:
#       Source.Name        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     season-0809  30/08/2008      Espanol   Valladolid     1     0   H     0
# 1     season-0809  30/08/2008     Valencia     Mallorca     3     0   H     2
# 2     season-0809  31/08/2008   Ath Bilbao      Almeria     1     3   A     0
# 3     season-0809  31/08/2008   Ath Madrid       Malaga     4     0   H     3
# 4     season-0809  31/08/2008        Betis   Recreativo     0     1   A     0
# 5     season-0809  31/08/2008    La Coruna  Real Madrid     2     1   H     1
# 6     season-0809  31/08/2008     Numancia    Barcelona     1     0   H     1
# 7     season-0809  31/08/2008      Osasuna   Villarreal     1     1   D     0
# 8     season-0809  31/08/2008    Santander      Sevilla     1     1   D     0
# 9     season-0809  31/08/2008     Sp Gijon       Getafe     1     2   A     1
# 10    season-0809  13/09/2008    Barcelona    Santander     1     1   D     0
# ...

# %%
#what is the win rate of HomeTeam ?

n_matches = df.shape[0]

n_features = df.shape[1] -1

n_homewin = len(df[df.FTR == 'H'])

win_rate = (float(n_homewin) / (n_matches)) * 100


print ("Total number of matches :{}".format(n_matches))
print ("Number of features:{}".format(n_features))
print ("Number of maches won by hom team:{}".format (n_homewin))
print ("win rate of home team:{:.2f}%" .format(win_rate))
# Out:
# Total number of matches :4070
# Number of features:21
# Number of maches won by hom team:1957
# win rate of home team:48.08%

# %%
import pandas as pd 
import numpy as np
import IPython.display

#checking for null values in all
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
df.head()
feature_table = df.ix[:,:22]
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
import pandas as pd 
import numpy as np
import IPython.display

#checking for null values in all
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
#Team, Home Goals Score, Away Goals Score, Attack Strength, Home Goals Conceded, Away Goals Conceded, Defensive Strength
table_df = pd.DataFrame(columns=('Team','HGS','AGS','HAS','AAS','HGC','AGC','HDS','ADS',))
table_df = table_df[:-10]

# %%
arrange_home = df[:-10]
df.shape[0]
# Out:
# 4070

# %%
#what is average number of goals for home and away team ?

avg_home_scored = df.FTHG.sum()*1.0 / df.shape[0]
avg_away_scored = df.FTAG.sum()*1.0 / df.shape[0]
avg_home_conceded = avg_away_scored
avg_away_conceded = avg_home_scored

print("Average number of goals at home",avg_home_scored)
print("Average number of goals away", avg_away_scored)
print("Average number of goals conceded at home",avg_home_conceded)
print("Average number of goals conceded away",avg_away_conceded)
# Out:
# Average number of goals at home 1.6115479115479114
# Average number of goals away 1.1501228501228502
# Average number of goals conceded at home 1.1501228501228502
# Average number of goals conceded away 1.6115479115479114

# %%
arrange_home = df.groupby('HomeTeam')
arrange_away = df.groupby('AwayTeam')

# %%
list(arrange_home)[:-1]
# Out:
# [('Alaves',
#         Source.Name        Date HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
#   3056  season-1617  28/08/2016   Alaves     Sp Gijon     0     0   D     0
#   3079  season-1617  19/09/2016   Alaves    La Coruna     0     0   D     0
#   3099  season-1617  26/09/2016   Alaves      Granada     3     1   H     0
#   3115  season-1617  16/10/2016   Alaves       Malaga     1     1   D     1
#   3131  season-1617  29/10/2016   Alaves  Real Madrid     1     4   A     1
#   3155  season-1617  20/11/2016   Alaves      Espanol     0     1   A     0
#   3174  season-1617  04/12/2016   Alaves   Las Palmas     1     1   D     1
#   3190  season-1617  16/12/2016   Alaves        Betis     1     0   H     0
#   3220  season-1617  21/01/2017   Alaves      Leganes     2     2   D     1
#   3230  season-1617  28/01/2017   Alaves   Ath Madrid     0     0   D     0
#   3248  season-1617  11/02/2017   Alaves    Barcelona     0     6   A     0
# ...

# %%
list(arrange_away)[:-1]
# Out:
# [('Alaves',
#         Source.Name        Date     HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  \
#   3045  season-1617  21/08/2016   Ath Madrid   Alaves     1     1   D     0
#   3061  season-1617  10/09/2016    Barcelona   Alaves     1     2   A     0
#   3089  season-1617  22/09/2016     Valencia   Alaves     2     1   H     1
#   3104  season-1617  01/10/2016      Sevilla   Alaves     2     1   H     0
#   3123  season-1617  22/10/2016     Sociedad   Alaves     3     0   H     1
#   3143  season-1617  05/11/2016      Osasuna   Alaves     0     1   A     0
#   3168  season-1617  27/11/2016   Villarreal   Alaves     0     2   A     0
#   3187  season-1617  11/12/2016        Eibar   Alaves     0     0   D     0
#   3204  season-1617  08/01/2017   Ath Bilbao   Alaves     0     0   D     0
#   3213  season-1617  15/01/2017        Celta   Alaves     1     0   H     0
#   3245  season-1617  05/02/2017     Sp Gijon   Alaves     2     4   A     0
# ...

# %%
table_df.Team = arrange_home.HomeTeam.all().values
table_df.HGS = arrange_home.FTHG.sum().values
table_df.HGC = arrange_home.FTAG.sum().values
table_df.AGS = arrange_away.FTAG.sum().values
table_df.AGC = arrange_away.FTHG.sum().values

# %%
#Assuming number of home games = number of away games
numb_games = df.shape[0]/38

# %%
table_df.HAS = (df.HGS / numb_games) / avg_home_scored
table_df.AAS = (df.AGS / numb_games) / avg_away_scored
table_df.HDS = (df.HGC / numb_games) / avg_home_conceded
table_df.ADS = (df.AGC / numb_games) / avg_away_conceded
table_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-5d4f4ca30423> in <module>
# ----> 1 table_df.HAS = (df.HGS / numb_games) / avg_home_scored
#       2 table_df.AAS = (df.AGS / numb_games) / avg_away_scored
#       3 table_df.HDS = (df.HGC / numb_games) / avg_home_conceded
#       4 table_df.ADS = (df.AGC / numb_games) / avg_away_conceded
#       5 table_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'HGS'

# %%
table_df.HAS = (df.HGS / numb_games) / avg_home_scored
table_df.AAS = (df.AGS / numb_games) / avg_away_scored
table_df.HDS = (df.HGC / numb_games) / avg_home_conceded
table_df.ADS = (df.AGC / numb_games) / avg_away_conceded
table_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-5d4f4ca30423> in <module>
# ----> 1 table_df.HAS = (df.HGS / numb_games) / avg_home_scored
#       2 table_df.AAS = (df.AGS / numb_games) / avg_away_scored
#       3 table_df.HDS = (df.HGC / numb_games) / avg_home_conceded
#       4 table_df.ADS = (df.AGC / numb_games) / avg_away_conceded
#       5 table_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'HGS'

# %%
import matplotlib.pyplot as plt
import requests #download from football data
import io 
#from __future__ import division
import seaborn as sns
# %matplotlib inline 
import IPython.display


has_plot = sns.barplot(table_df.Team,table_df.HAS)
for item in has_plot.get_xticklabels():
    item.set_rotation(90)

# %%
''' feature_table contains all the fixtures in the current season.
ftr = full time result
hst = home shots on target
ast = away shots on target
'''

feature_table = feature_table[['HomeTeam','AwayTeam','FTR','HST','AST']]
f_HAS = []
f_HDS = []
f_AAS = []
f_ADS = []
for index,row in feature_table.iterrows():
    f_HAS.append(table_df[table_df['Team'] == row['HomeTeam']]['HAS'].values[0])
    f_HDS.append(table_df[table_df['Team'] == row['HomeTeam']]['HDS'].values[0])
    f_AAS.append(table_df[table_df['Team'] == row['AwayTeam']]['AAS'].values[0])
    f_ADS.append(table_df[table_df['Team'] == row['AwayTeam']]['ADS'].values[0])
    
feature_table['HAS'] = f_HAS
feature_table['HDS'] = f_HDS
feature_table['AAS'] = f_AAS
feature_table['ADS'] = f_ADS
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\pandas\core\ops.py:1167: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d44400a042d7> in <module>
#      11 f_ADS = []
#      12 for index,row in feature_table.iterrows():
# ---> 13     f_HAS.append(table_df[table_df['Team'] == row['HomeTeam']]['HAS'].values[0])
#      14     f_HDS.append(table_df[table_df['Team'] == row['HomeTeam']]['HDS'].values[0])
#      15     f_AAS.append(table_df[table_df['Team'] == row['AwayTeam']]['AAS'].values[0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
# ...

# %%
# Visualising distribution of data
import pandas as pd 
import xgboost as xgb
import sklearn as s 
import matplotlib 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from IPython.display import display 
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df[['FTHG','FTAG','HTHG','HTAG']], figsize=(10,10))
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   if sys.path[0] == '':
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020E0E700E10>,
# ...
#       dtype=object)

# %%
# Separate into feature set and target variable
#FTR = Full Time Result (H=Home Win, D=Draw, A=Away Win)

import pandas as pd 
import numpy as np
import xgboost as xgb
import sklearn as s 
import matplotlib 
import tensorflow as tf 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from IPython.display import display 
df = pd.read_csv("C:/Users/patel/Desktop/tap.csv")


X_all = df.drop(['FTR'],1)
y_all = df['FTR']

# Standardising the data.
from sklearn.preprocessing import scale

#Center to the mean and component wise scale to unit variance.
cols = [['FTHG','FTAG','HTHG','HTAG']]
for col in cols:
    X_all[col] = scale(X_all[col])
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DataConversionWarning: Data with input dtype int64 were all converted to float64 by the scale function.

# %%
X_all.HM1 = X_all.HM1.astype('str')
X_all.HM2 = X_all.HM2.astype('str')
X_all.HM3 = X_all.HM3.astype('str')
X_all.AM1 = X_all.AM1.astype('str')
X_all.AM2 = X_all.AM2.astype('str')
X_all.AM3 = X_all.AM3.astype('str')
def preprocess_features(X):
    output = pd.DataFrame(index = X.index)
    for col, col_df in X.iteritems():
             if col_df.dtype == object:
                col_df = pd.get_dummies(col_df, prefix = col)
    output = output.join(col_df)
    return output
X_all = preprocess_features(X_all)
print("Processed feature columns ({} total features):\n{}".format(len(X_all.columns), list(X_all.columns)))
print ("\nFeature values:")
display (X_all)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b9b308bba786> in <module>
# ----> 1 X_all.HM1 = X_all.HM1.astype('str')
#       2 X_all.HM2 = X_all.HM2.astype('str')
#       3 X_all.HM3 = X_all.HM3.astype('str')
#       4 X_all.AM1 = X_all.AM1.astype('str')
#       5 X_all.AM2 = X_all.AM2.astype('str')
#
# NameError: name 'X_all' is not defined
